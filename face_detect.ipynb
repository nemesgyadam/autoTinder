# %%
from mtcnn.mtcnn import MTCNN
import cv2
detector = MTCNN()
import matplotlib.pyplot as plt
# %matplotlib inline
import uuid
# Out:
# C:\Users\Nemes\anaconda3\envs\tf\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Nemes\anaconda3\envs\tf\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\Nemes\anaconda3\envs\tf\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\Nemes\anaconda3\envs\tf\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
img = cv2.imread('test2.jpg')

print(detector.detect_faces(img))
# Out:
# [{'box': [219, 44, 89, 119], 'confidence': 0.9998648166656494, 'keypoints': {'left_eye': (251, 91), 'right_eye': (293, 103), 'nose': (266, 120), 'mouth_left': (241, 137), 'mouth_right': (274, 147)}}, {'box': [113, 671, 23, 34], 'confidence': 0.9313876628875732, 'keypoints': {'left_eye': (118, 681), 'right_eye': (128, 679), 'nose': (119, 687), 'mouth_left': (120, 696), 'mouth_right': (128, 695)}}, {'box': [298, 461, 51, 64], 'confidence': 0.7451805472373962, 'keypoints': {'left_eye': (330, 482), 'right_eye': (346, 491), 'nose': (341, 502), 'mouth_left': (317, 507), 'mouth_right': (329, 515)}}]

# %%
score_threshold = 0.9
size_threshold = 1000
for face in detector.detect_faces(img):
    x, y, w, h = face['box']
    score = face['confidence']
    print(h*w)
    print(score)
    if h*w > size_threshold and score > score_threshold:
        img = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
        
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.show()
# Out:
# 10591
# 0.9998648166656494
# 782
# 0.9313876628875732
# 3264
# 0.7451805472373962

# %%
source = 'resources/imgs/'
target ='resources/faces/unlabeled/'
score_threshold = 0.9
size_threshold = 1000
for filename in os.listdir(source):
    try:
        img = cv2.imread(source+filename)
        for face in detector.detect_faces(img):
            x, y, w, h = face['box']
            score = face['confidence']

            if h*w > size_threshold and score > score_threshold:
                face=img[y:y+h, x:x+w]
                cv2.imwrite(target+str(uuid.uuid4())+'.jpg', face)
    except Exception as e:
        #print(e)
        #break
        ...

# %%
source = 'resources/imgs/+/'
target ='resources/faces/nemes/+/'
score_threshold = 0.9
size_threshold = 1000
for filename in os.listdir(source):
    try:
        img = cv2.imread(source+filename)
        for face in detector.detect_faces(img):
            x, y, w, h = face['box']
            score = face['confidence']

            if h*w > size_threshold and score > score_threshold:
                face=img[y:y+h, x:x+w]
                cv2.imwrite(target+str(uuid.uuid4())+'.jpg', face)
    except Exception as e:
        #print(e)
        #break
        ...

# %%
source = 'resources/imgs/-/'
target ='resources/faces/nemes/-/'
score_threshold = 0.9
size_threshold = 1000
for filename in os.listdir(source):
    try:
        img = cv2.imread(source+filename)
        for face in detector.detect_faces(img):
            x, y, w, h = face['box']
            score = face['confidence']

            if h*w > size_threshold and score > score_threshold:
                face=img[y:y+h, x:x+w]
                cv2.imwrite(target+str(uuid.uuid4())+'.jpg', face)
    except Exception as e:
        #print(e)
        #break
        ...
